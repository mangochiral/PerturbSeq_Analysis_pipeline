# %%
import scanpy as sc
import pandas as pd
import numpy as np
import sys, os
import glob
import random

# %%
# Check the cell counts in and  out and guides list
exp_meta = pd.read_csv('/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/gw-CRISPRa/Diff053/expirements_meta.csv')

# %%
lanes =  exp_meta.columns
exprs = exp_meta.iloc[:,0]
path = '/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/gw-CRISPRa_from_cluster'
list_preprocessed = []
for lane in lanes:
    for expr in exprs:
        pattern = glob.glob(os.path.join(path, f"{expr}_{lane}", "*crispr_preprocessed.h5ad"))[0]
        list_preprocessed.append(pattern)

# %%
random.seed(2026)
file_check = random.choice(list_preprocessed)
file_check
# Out:
# '/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/gw-CRISPRa_from_cluster/D1_392i_Rest_lane8/D1_392i_Rest_crispr_preprocessed.h5ad'

# %%
cripr_a = sc.read_h5ad('/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/gw-CRISPRa_from_cluster/D1_392i_Rest_lane1/D1_392i_Rest_crispr_preprocessed.h5ad')
cripr_a
# Out:
# AnnData object with n_obs × n_vars = 24768 × 1854
#     obs: 'library_id', 'lane_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'sgrna_id', 'perturbed_gene_name', 'perturbation_type', 'feature_types', 'genome', 'pattern', 'read', 'sequence', 'n_cells', 'mean_counts', 'total_counts', 'nonz_means'

# %%
gex_a = sc.read_h5ad('/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/gw-CRISPRa_from_cluster/D1_392i_Rest_lane1/D1_392i_Rest_gex_preprocessed.h5ad')
gex_a
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 gex_a = sc.read_h5ad('/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/gw-CRISPRa_from_cluster/D1_392i_Rest_lane1/D1_392i_Rest_gex_preprocessed.h5ad')
#       2 gex_a
#
# File ~/ron_perturb_seq_analysis/gw_CRISPRa_Chandrima/branch_code_env/lib/python3.11/site-packages/anndata/_io/h5ad.py:262, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     256         raise NotImplementedError(msg)
#     258 rdasp = partial(
#     259     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     260 )
# --> 262 with h5py.File(filename, "r") as f:
#     264     def callback(func, elem_name: str, elem, iospec):
#     265         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# ...

# %%
adata.n_obs
# Out:
# 532369

# %%
df = pd.read_csv('/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/gw-CRISPRa/Diff053/cellranger/CRISPRia_Cellanome_lane1/per_sample_outs/D1_392i_Rest/count/sample_filtered_barcodes.csv')

# %%
df.shape
# Out:
# (24767, 2)
